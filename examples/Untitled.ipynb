# %%
from mlblocks import discovery, MLPipeline

discovery.find_pipelines()
# Out:
# ['graph.graph_matching.networkx.xgboost',
#  'graph.link_prediction.networkx.xgboost',
#  'image.classification.hog.random_forest',
#  'image.classification.hog.xgboost',
#  'image.classification.resnet50.xgboost',
#  'image.regression.hog.random_forest',
#  'image.regression.hog.xgboost',
#  'image.regression.resnet50.xgboost',
#  'multi_table.classification.featuretools.xgboost',
#  'single_table.classification.categorical_encoder.logit',
#  'single_table.classification.categorical_encoder.random_forest',
#  'single_table.classification.categorical_encoder.xgboost',
#  'single_table.classification.mlprimitives.logit',
#  'single_table.classification.mlprimitives.random_forest',
#  'single_table.classification.mlprimitives.xgboost',
#  'single_table.classification.mlprimitives_text.xgboost',
#  'single_table.regression.text',
#  'single_table.regression.xgb',
#  'text.classification.lstm',
#  'timeseries.forecasting.arima',
#  'timeseries.forecasting.impute.scale.arima',
# ...

# %%
pipelines = discovery.find_pipelines()

MLPipeline('single_table.regression.xgb').get_diagram()
